# %% [markdown]
# ## Sentiment Analysis
#
# Use the newsapi to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
#     1.Which coin had the highest mean positive score?
#     2. Which coin had the highest negative score?
#     3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
load_dotenv()

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/shahriarshochi/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
api_key =("34d0473c17c24afcb1997aad110bb7cc")

# %%
#Create a newsapi client

from newsapi import NewsApiClient
newsapi = NewsApiClient(api_key = api_key)

# %%
# Fetch the Bitcoin news articles
bitcoin_articles = newsapi.get_everything(q="Bitcoin", language="en", sort_by="relevancy")

# %%
# Fetch the Ethereum news articles

ethereum_articles = newsapi.get_everything(q='ethereum', language='en')

# %%
# Create the Bitcoin sentiment scores DataFrame
bitcoin_sentiments = []

for article in bitcoin_articles["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        bitcoin_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
bitcoin_df = pd.DataFrame(bitcoin_sentiments)
bitcoin_df.head()
# Out:
#                                                 text        date  compound  \
# 0  Miners voluntarily powered down as energy dema...  2022-07-12    0.1531
# 1  You gotta hand it to some people for being imp...  2022-07-25    0.5994
# 2  People in Russia will soon no longer be allowe...  2022-07-16    0.0516
# 3  Three Arrows Capital, one of the crypto indust...  2022-06-29   -0.7579
# 4  Elon Musk-owned electric vehicle making compan...  2022-07-21    0.2023
#
#    positive  negative  neutral
# 0     0.057     0.041    0.902
# 1     0.130     0.034    0.835
# 2     0.088     0.057    0.855
# 3     0.000     0.169    0.831
# 4     0.053     0.000    0.947

# %%
# Create the Ethereum sentiment scores DataFrame
ethereum_sentiments = []

for article in ethereum_articles["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        ethereum_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
ethereum_df = pd.DataFrame(ethereum_sentiments)
ethereum_df.head()
# Out:
#                                                 text        date  compound  \
# 0  Less than two weeks into its soft launch, Game...  2022-07-23   -0.1531
# 1  Axie Infinity was the prime example of crypto ...  2022-07-06    0.2263
# 2  The Ethereum Merge is significant, and not jus...  2022-07-25    0.2023
# 3  Ethereum and Bitcoin have nearly become househ...  2022-07-11    0.2500
# 4  Whether you own cryptocurrency or not, the Eth...  2022-07-15    0.0000
#
#    positive  negative  neutral
# 0     0.000     0.045    0.955
# 1     0.077     0.000    0.923
# 2     0.048     0.000    0.952
# 3     0.065     0.000    0.935
# 4     0.000     0.000    1.000

# %%
# Describe the Bitcoin Sentiment

bitcoin_df.describe()
# Out:
#          compound    positive    negative    neutral
# count  100.000000  100.000000  100.000000  100.00000
# mean     0.020498    0.061810    0.054560    0.88360
# std      0.441949    0.065289    0.067278    0.08115
# min     -0.862500    0.000000    0.000000    0.64100
# 25%     -0.296000    0.000000    0.000000    0.83100
# 50%      0.000000    0.059500    0.000000    0.89050
# 75%      0.361200    0.093750    0.092250    0.93725
# max      0.888500    0.271000    0.249000    1.00000

# %%
# Describe the Ethereum Sentiment

ethereum_df.describe()
# Out:
#          compound    positive    negative     neutral
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.148119    0.077230    0.045380    0.877360
# std      0.447397    0.071638    0.068501    0.089522
# min     -0.936600    0.000000    0.000000    0.633000
# 25%     -0.057025    0.000000    0.000000    0.826500
# 50%      0.220350    0.069500    0.000000    0.896000
# 75%      0.458800    0.116250    0.082000    0.935250
# max      0.921600    0.299000    0.354000    1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Bitcoin has the highest mean positive score
#
# Q: Which coin had the highest compound score?
#
# A: Bitcoin has the highest compound score
#
# Q. Which coin had the highest positive score?
#
# A: Bitcoin has the highest positive score

# %% [markdown]
# ### Natural Language Processing

# %% [markdown]
# ### Tokenizer

# %% [markdown]
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
#
#     1. Lowercase each word.
#     2. Remove Punctuation.
#     3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
#Instantiate the lemmatizer
lemmatizer = WordNetLemmatizer()
#Create a list of stopwords
sw = set(stopwords.words('english'))

# %%
#Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    #Remove the punctuation from text
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('',text)
    
    #Create a tokenized list of the words
    words = word_tokenize(text)
    
    #Lemmatize words into root words
    lem = [lemmatizer.lemmatize(word) for word in words]
    
    #Convert the words to lowercase
    re_words = word_tokenize(re_clean)
    
    #Remove the stop words
    re_result = [word.lower() for word in re_words if word.lower() not in sw]
    
    return re_result

# %%
#create a new tokens column for Bitcoin
bitcoin_df['tokens'] = bitcoin_df['text'].apply(tokenizer)
bitcoin_df.head()
# Out:
#                                                 text        date  compound  \
# 0  Miners voluntarily powered down as energy dema...  2022-07-12    0.1531
# 1  You gotta hand it to some people for being imp...  2022-07-25    0.5994
# 2  People in Russia will soon no longer be allowe...  2022-07-16    0.0516
# 3  Three Arrows Capital, one of the crypto indust...  2022-06-29   -0.7579
# 4  Elon Musk-owned electric vehicle making compan...  2022-07-21    0.2023
#
#    positive  negative  neutral  \
# 0     0.057     0.041    0.902
# 1     0.130     0.034    0.835
# 2     0.088     0.057    0.855
# 3     0.000     0.169    0.831
# 4     0.053     0.000    0.947
#
#                                               tokens
# 0  [miners, voluntarily, powered, energy, demand,...
# 1  [got, ta, hand, people, impetuous, even, face,...
# 2  [people, russia, soon, longer, allowed, use, d...
# 3  [three, arrows, capital, one, crypto, industry...
# 4  [elon, muskowned, electric, vehicle, making, c...

# %%
#Create a new tokens column for Ethereum
ethereum_df['tokens'] = ethereum_df['text'].apply(tokenizer)
ethereum_df.head()
# Out:
#                                                 text        date  compound  \
# 0  Less than two weeks into its soft launch, Game...  2022-07-23   -0.1531
# 1  Axie Infinity was the prime example of crypto ...  2022-07-06    0.2263
# 2  The Ethereum Merge is significant, and not jus...  2022-07-25    0.2023
# 3  Ethereum and Bitcoin have nearly become househ...  2022-07-11    0.2500
# 4  Whether you own cryptocurrency or not, the Eth...  2022-07-15    0.0000
#
#    positive  negative  neutral  \
# 0     0.000     0.045    0.955
# 1     0.077     0.000    0.923
# 2     0.048     0.000    0.952
# 3     0.065     0.000    0.935
# 4     0.000     0.000    1.000
#
#                                               tokens
# 0  [less, two, weeks, soft, launch, gamestops, nf...
# 1  [axie, infinity, prime, example, crypto, gamin...
# 2  [ethereum, merge, significant, people, crypto,...
# 3  [ethereum, bitcoin, nearly, become, household,...
# 4  [whether, cryptocurrency, ethereum, merge, big...

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
#Generate the Bitcoin N-grams where N=2
bitcoin_a = tokenizer(bitcoin_df.text.str.cat())
bitcoin_counts = Counter(ngrams(bitcoin_a,n=2))
print(dict(bitcoin_counts))
# Out:
# {('miners', 'voluntarily'): 1, ('voluntarily', 'powered'): 1, ('powered', 'energy'): 1, ('energy', 'demand'): 1, ('demand', 'prices'): 1, ('prices', 'spiked'): 1, ('spiked', 'aerial'): 1, ('aerial', 'view'): 1, ('view', 'whinstone'): 1, ('whinstone', 'us'): 1, ('us', 'bitcoin'): 1, ('bitcoin', 'mining'): 2, ('mining', 'facility'): 1, ('facility', 'rockdale'): 1, ('rockdale', 'texas'): 1, ('texas', 'october'): 1, ('october', 'th'): 1, ('th', 'long'): 1, ('long', 'sheds'): 1, ('sheds', 'north'): 1, ('north', 'ameri'): 1, ('ameri', 'charsyou'): 1, ('charsyou', 'got'): 1, ('got', 'ta'): 1, ('ta', 'hand'): 1, ('hand', 'people'): 1, ('people', 'impetuous'): 1, ('impetuous', 'even'): 1, ('even', 'face'): 1, ('face', 'extraordinary'): 1, ('extraordinary', 'odds'): 1, ('odds', 'imagine'): 1, ('imagine', 'looking'): 1, ('looking', 'single'): 1, ('single', 'hard'): 1, ('hard', 'drive'): 3, ('drive', 'amidst'): 1, ('amidst', 'literal'): 1, ('literal', 'heap'): 1, ('heap', 'trash'): 1, ('trash', 'well'): 1, ('well', 'thats'): 1, ('thats', 'one'): 1, ('one', 'uk'): 1, ('uk', 'mans'): 1, ('mans', 'goal'): 1, ('goal', 'charspeople'): 1, ('charspeople', 'russia'): 1, ('russia', 'soon'): 1, ('soon', 'longer'): 1, ('longer', 'allowed'): 1, ('allowed', 'use'): 1, ('use', 'digital'): 2, ('digital', 'assets'): 4, ('assets', 'form'): 1, ('form', 'payment'): 1, ('payment', 'russian'): 1, ('russian', 'president'): 1, ('president', 'vladimir'): 1, ('vladimir', 'putin'): 1, ('putin', 'signed'): 1, ('signed', 'bill'): 1, ('bill', 'law'): 1, ('law', 'prohibiting'): 1, ('prohibiting', 'use'): 1, ('assets', 'charsthree'): 1, ('charsthree', 'arrows'): 1, ('arrows', 'capital'): 4, ('capital', 'one'): 1, ('one', 'crypto'): 1, ('crypto', 'industrys'): 1, ('industrys', 'biggest'): 1, ('biggest', 'sinking'): 1, ('sinking', 'ships'): 1, ('ships', 'finally'): 1, ('finally', 'put'): 1, ('put', 'miseryon'): 1, ('miseryon', 'tuesday'): 1, ('tuesday', 'distressed'): 1, ('distressed', 'crypto'): 1, ('crypto', 'hedge'): 4, ('hedge', 'fund'): 4, ('fund', 'ordered'): 1, ('ordered', 'liquidation'): 1, ('liquidation', 'virgin'): 1, ('virgin', 'charselon'): 1, ('charselon', 'muskowned'): 1, ('muskowned', 'electric'): 1, ('electric', 'vehicle'): 2, ('vehicle', 'making'): 1, ('making', 'company'): 1, ('company', 'tesla'): 1, ('tesla', 'sold'): 1, ('sold', 'significant'): 1, ('significant', 'amount'): 1, ('amount', 'bitcoin'): 1, ('bitcoin', 'holdings'): 6, ('holdings', 'firm'): 1, ('firm', 'said'): 1, ('said', 'statement'): 2, ('statement', 'reporting'): 1, ('reporting', 'earnings'): 1, ('earnings', 'q'): 1, ('q', 'company'): 1, ('company', 'said'): 2, ('said', 'charsgrayscale'): 1, ('charsgrayscale', 'investments'): 1, ('investments', 'announced'): 1, ('announced', 'intention'): 1, ('intention', 'sue'): 1, ('sue', 'securities'): 1, ('securities', 'exchange'): 4, ('exchange', 'commission'): 3, ('commission', 'us'): 1, ('us', 'regulator'): 1, ('regulator', 'rejected'): 1, ('rejected', 'proposal'): 2, ('proposal', 'list'): 2, ('list', 'spot'): 2, ('spot', 'bitcoin'): 3, ('bitcoin', 'etfjust'): 1, ('etfjust', 'hour'): 1, ('hour', 'sec'): 1, ('sec', 'charswhat'): 1, ('charswhat', 'difference'): 1, ('difference', 'year'): 1, ('year', 'makes'): 1, ('makes', 'making'): 1, ('making', 'big'): 1, ('big', 'plays'): 1, ('plays', 'bitcoin'): 1, ('bitcoin', 'tesla'): 1, ('tesla', 'jettisoned'): 1, ('jettisoned', 'million'): 1, ('million', 'worth'): 1, ('worth', 'cryptocurrency'): 1, ('cryptocurrency', 'second'): 1, ('second', 'quarter'): 1, ('quarter', 'trimming'): 1, ('trimming', 'bitcoin'): 1, ('holdings', 'charstesla'): 1, ('charstesla', 'released'): 1, ('released', 'q'): 1, ('q', 'earnings'): 1, ('earnings', 'wednesday'): 1, ('wednesday', 'results'): 1, ('results', 'mixed'): 1, ('mixed', 'elon'): 1, ('elon', 'musks'): 1, ('musks', 'electric'): 1, ('vehicle', 'maker'): 1, ('maker', 'reported'): 1, ('reported', 'billion'): 1, ('billion', 'secondquarter'): 1, ('secondquarter', 'profit'): 1, ...

# %%
#Generate the ethereum N-grams where N=2
ethereum_a = tokenizer(ethereum_df.text.str.cat())
ethereum_counts= Counter(ngrams(ethereum_a,n=2))
print(dict(ethereum_counts))
# Out:
# {('less', 'two'): 1, ('two', 'weeks'): 1, ('weeks', 'soft'): 1, ('soft', 'launch'): 1, ('launch', 'gamestops'): 1, ('gamestops', 'nft'): 1, ('nft', 'marketplace'): 8, ('marketplace', 'already'): 1, ('already', 'courting'): 1, ('courting', 'controversy'): 1, ('controversy', 'among'): 1, ('among', 'nfts'): 1, ('nfts', 'listed'): 1, ('listed', 'platform'): 1, ('platform', 'artwork'): 1, ('artwork', 'called'): 1, ('called', 'falling'): 3, ('falling', 'man'): 3, ('man', 'spotted'): 1, ('spotted', 'web'): 1, ('web', 'charsaxie'): 1, ('charsaxie', 'infinity'): 1, ('infinity', 'prime'): 1, ('prime', 'example'): 1, ('example', 'crypto'): 1, ('crypto', 'gaming'): 1, ('gaming', 'last'): 1, ('last', 'year'): 4, ('year', 'playtoearn'): 1, ('playtoearn', 'formula'): 1, ('formula', 'helped'): 1, ('helped', 'reach'): 1, ('reach', 'million'): 1, ('million', 'daily'): 1, ('daily', 'active'): 1, ('active', 'users'): 1, ('users', 'last'): 1, ('last', 'november'): 1, ('november', 'came'): 1, ('came', 'crashing'): 1, ('crashing', 'charsthe'): 1, ('charsthe', 'ethereum'): 1, ('ethereum', 'merge'): 3, ('merge', 'significant'): 1, ('significant', 'people'): 1, ('people', 'crypto'): 1, ('crypto', 'works'): 1, ('works', 'one'): 1, ('one', 'form'): 1, ('form', 'another'): 1, ('another', 'since'): 1, ('since', 'longdelayed'): 2, ('longdelayed', 'merge'): 2, ('merge', 'see'): 2, ('see', 'second'): 1, ('second', 'biggest'): 2, ('biggest', 'blockchain'): 1, ('blockchain', 'reduce'): 1, ('reduce', 'car'): 1, ('car', 'charsethereum'): 1, ('charsethereum', 'bitcoin'): 1, ('bitcoin', 'nearly'): 1, ('nearly', 'become'): 1, ('become', 'household'): 1, ('household', 'names'): 1, ('names', 'however'): 1, ('however', 'theyre'): 1, ('theyre', 'often'): 1, ('often', 'mentioned'): 1, ('mentioned', 'tandem'): 1, ('tandem', 'theyre'): 1, ('theyre', 'far'): 1, ('far', 'samebitcoin'): 1, ('samebitcoin', 'created'): 1, ('created', 'alternative'): 1, ('alternative', 'decentralized'): 1, ('decentralized', 'currency'): 1, ('currency', 'charswhether'): 1, ('charswhether', 'cryptocurrency'): 1, ('cryptocurrency', 'ethereum'): 2, ('merge', 'big'): 1, ('big', 'deal'): 1, ('deal', 'works'): 1, ('works', 'since'): 1, ('see', 'ethereum'): 1, ('ethereum', 'secondbiggest'): 1, ('secondbiggest', 'blockchain'): 1, ('blockchain', 'behind'): 1, ('behind', 'bitcoin'): 1, ('bitcoin', 'become'): 1, ('become', 'nearly'): 1, ('nearly', 'charsethereum'): 1, ('charsethereum', 'improve'): 1, ('improve', 'upon'): 1, ('upon', 'scalability'): 1, ('scalability', 'completion'): 1, ('completion', 'socalled'): 1, ('socalled', 'surge'): 1, ('surge', 'cofounder'): 1, ('cofounder', 'vitalik'): 1, ('vitalik', 'buterin'): 1, ('buterin', 'said'): 1, ('said', 'thursdayat'): 1, ('thursdayat', 'ethereum'): 1, ('ethereum', 'community'): 1, ('community', 'conference'): 1, ('conference', 'paris'): 1, ('paris', 'addressed'): 1, ('addressed', 'overall'): 1, ('overall', 'charsits'): 1, ('charsits', 'way'): 1, ('way', 'alltimehigh'): 1, ('alltimehigh', 'ether'): 1, ('ether', 'cryptocurrency'): 1, ('cryptocurrency', 'showing'): 1, ('showing', 'signs'): 1, ('signs', 'life'): 1, ('life', 'long'): 1, ('long', 'downward'): 1, ('downward', 'spiral'): 1, ('spiral', 'began'): 1, ('began', 'april'): 1, ('april', 'following'): 1, ('following', 'news'): 1, ('news', 'longawaited'): 1, ('longawaited', 'ethereum'): 1, ('merge', 'co'): 1, ('co', 'charsover'): 1, ('charsover', 'last'): 1, ('last', 'month'): 1, ('month', 'ether'): 1, ('ether', 'significantly'): 1, ('significantly', 'outperformed'): 1, ('outperformed', 'bitcoin'): 1, ('bitcoin', 'enthusiasm'): 1, ('enthusiasm', 'grows'): 1, ('grows', 'ahead'): 1, ('ahead', 'highly'): 1, ('highly', 'anticipated'): 1, ('anticipated', 'merge'): 1, ('merge', 'event'): 1, ('event', 'ethereum'): 1, ('ethereum', 'secondlargest'): 1, ('secondlargest', 'cryptocurrency'): 2, ('cryptocurrency', 'hovering'): 1, ('hovering', 'charsdefi'): 1, ('charsdefi', 'called'): 1, ('called', 'wild'): 1, ('wild',  ...

# %%
#Function token_count generates the top 10 words for a given coin
def token_count(tokens,N=3):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
#Use token_count to get the top 10 words for Bitcoin
bitcoin_top_10 = token_count(bitcoin_a,10)
bitcoin_top_10
# Out:
# [('bitcoin', 41),
#  ('crypto', 29),
#  ('cryptocurrency', 24),
#  ('reuters', 24),
#  ('said', 14),
#  ('digital', 13),
#  ('july', 11),
#  ('money', 11),
#  ('us', 9),
#  ('wednesday', 9)]

# %%
#Use token_count to get the top 10 words for Ethereum
ethereum_top_10 = token_count(ethereum_a,10)
ethereum_top_10
# Out:
# [('crypto', 32),
#  ('market', 19),
#  ('cryptocurrency', 18),
#  ('ethereum', 17),
#  ('nft', 16),
#  ('charsthe', 14),
#  ('investors', 14),
#  ('charswhat', 14),
#  ('last', 12),
#  ('one', 12)]

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize']=[20.0,10.0]

# %%
#Generate the Bitcoin word cloud
wc = WordCloud().generate(bitcoin_df.text.str.cat())
plt.imshow(wc)

# %%
#Generate the Ethereum word cloud
wc = WordCloud().generate(ethereum_df.text.str.cat())
plt.imshow(wc)

# %% [markdown]
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
#Download the language model for spacy
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.3.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.3.0/en_core_web_sm-3.3.0-py3-none-any.whl (12.8 MB)
#      |████████████████████████████████| 12.8 MB 4.0 MB/s eta 0:00:01
# Requirement already satisfied: spacy<3.4.0,>=3.3.0.dev0 in /Users/shahriarshochi/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from en-core-web-sm==3.3.0) (3.3.0)
# Requirement already satisfied: pathy>=0.3.5 in /Users/shahriarshochi/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (0.6.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/shahriarshochi/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.4.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/shahriarshochi/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.3.0)
# Requirement already satisfied: jinja2 in /Users/shahriarshochi/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.11.3)
# Requirement already satisfied: numpy>=1.15.0 in /Users/shahriarshochi/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.21.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/shahriarshochi/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.0.6)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/shahriarshochi/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.0.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/shahriarshochi/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.0.7)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /Users/shahriarshochi/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (0.9.1)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /Users/shahriarshochi/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.10.0.2)
# Requirement already satisfied: thinc<8.1.0,>=8.0.14 in /Users/shahriarshochi/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (8.0.15)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/shahriarshochi/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.28.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /Users/shahriarshochi/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.8.2)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /Users/shahriarshochi/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (0.7.7)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/shahriarshochi/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.0.6)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /Users/shahriarshochi/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (0.4.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/shahriarshochi/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (4.64.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/shahriarshochi/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.0.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /Users/shahriarshochi/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /Users/shahriarshochi/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (21.3)
# Requirement already satisfied: setuptools in /Users/shahriarshochi/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (61.2.0)
# Requirement already satisfied: zipp>=0.5 in /Users/shahriarshochi/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from catalogue<2.1.0,>=2.0.6->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.7.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/shahriarshochi/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from packaging>=20.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.0.4)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /Users/shahriarshochi/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from pathy>=0.3.5->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (5.1.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/shahriarshochi/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/shahriarshochi/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in /Users/shahriarshochi/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/shahriarshochi/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.26.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/shahriarshochi/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from typer<0.5.0,>=0.3.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (8.0.4)
# Requirement already satisfied: importlib-metadata in /Users/shahriarshochi/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from click<9.0.0,>=7.1.1->typer<0.5.0,>=0.3.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (4.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/shahriarshochi/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from jinja2->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.0.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
#Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ## Bitcoin NER

# %%
#Concentrate all the Bitcoin text together
concat_bitcoin = bitcoin_df.text.str.cat()
concat_bitcoin
# Out:
# 'Miners voluntarily powered down as energy demand and prices spiked \r\nAn aerial view of the Whinstone US Bitcoin mining facility in Rockdale, Texas, on October 9th, 2021. The long sheds at North Ameri… [+3770 chars]You gotta hand it to some people for being impetuous even in the face of extraordinary odds. Imagine looking for a single hard drive amidst a literal heap of trash. Well, thats been one UK mans goal … [+4091 chars]People in Russia will soon no longer be allowed to use digital assets as a form of payment. Russian president Vladimir Putin has signed a bill into law prohibiting the use of digital assets, such as … [+1436 chars]Three Arrows Capital, one of the crypto industrys biggest sinking ships, is finally being put out of its misery.\r\nOn Tuesday, the distressed crypto hedge fund was ordered into liquidation by a Virgin… [+2515 chars]Elon Musk-owned electric vehicle making company Tesla has sold a significant amount of its Bitcoin holdings, the firm said in a statement. Reporting its earnings for Q2, the company said that it had … [+2850 chars]Grayscale Investments has announced its intention to sue the Securities and Exchange Commission after the US regulator rejected its proposal to list a spot bitcoin ETF.\r\nJust an hour after the SEC re… [+1567 chars]What a difference a year makes. After making big plays in Bitcoin in 2021, Tesla jettisoned $936 million worth of the cryptocurrency in the second quarter of 2022, trimming its Bitcoin holdings by 75… [+1974 chars]Tesla released its 2022 Q2 earnings Wednesday and the results are mixed: Elon Musks electric vehicle maker reported $2.3 billion in second-quarter profit, down from a record $3.3 billion in the first… [+3324 chars]June 27 (Reuters) - Bitcoin miners have been forced to tap into their cryptocurrency stashes as a plunge in prices, rising energy costs and increased competition bite into profitability.\r\nThe number … [+3710 chars]July 19 (Reuters) - If you\'re waiting for a bitcoin recovery, you may have to sweat it out for months. That\'s the conclusion of some technical specialists seeking method from the madness.\r\nBitcoin\'s … [+3397 chars]July 12 (Reuters) - The shrimps of the crypto world have joined the whales in a glorious last stand to banish the bleak bitcoin winter.\r\nThese two contrasting groups are both HODLers - investors in b… [+3895 chars]What exactly happened after El Salvador president Nayib Bukele made Bitcoin a legal tender for the country? "As Bitcoin has dropped more than 50 percent of its value this year, there have been sugges… [+3401 chars]NEW YORK, July 20 (Reuters) - Bitcoin stumbled late on Wednesday after Tesla Inc (TSLA.O) said it converted about 75% of its purchases of the virtual token into fiat currency.\r\nThe world\'s largest cr… [+1274 chars]June 29 (Reuters) - The U.S. Securities and Exchange Commission on Wednesday said in a filing that it rejected a proposal to list a spot bitcoin exchange-traded fund by Grayscale, one of the world\'s … [+723 chars]June 30 (Reuters) - Bitcoin dropped 6.1% to $18,866.77 at 2004 GMT on Thursday, putting the biggest and best-known cryptocurrency down $1,226.41 from its previous close and down 60.9% from the year\'s… [+1098 chars]Tesla seems to be abandoning its ten-figure bitcoin bet amid a severe slump in cryptocurrency markets.\xa0\r\nThe electric-car maker said on Wednesday that it has sold approximately 75% of its bitcoin as … [+1260 chars]BRUSSELS, June 30 (Reuters) - Investment company Jacobi Asset Management said on Thursday that it would launch Europe\'s first bitcoin exchange-traded-fund (ETF) on the Euronext exchange, in a further… [+616 chars]Congressional Democrats are calling on the Environmental Protection Agency and Department of Energy to address the recent proliferation of cryptocurrency mining within the US. In a letter\r\n sent Frid… [+2231 chars]Speculation is that some investors have turned to bitcoin in order to protect their holdings from the impacts of hyperinf ...

# %%
#Run the NER processor on all of the text
bitcoin_doc = nlp(concat_bitcoin)
bitcoin_doc

#Add a title to the document
bitcoin_doc.user_data['Title'] = 'Bitcoin NER'

# %%
#Render the visualization
displacy.render(bitcoin_doc, style = 'ent')
# Out:
# </br>An aerial view of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Whinstone US Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  mining facility in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rockdale
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Texas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     October 9th, 2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . The long sheds at
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     North Ameri
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# … [+3770 chars]You gotta hand it to some people for being impetuous even in the face of extraordinary odds. Imagine looking for a single hard drive amidst a literal heap of trash. Well, thats been one
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     UK
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mans
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  goal … [+4091 chars]People in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  will soon no longer be allowed to use digital assets as a form of payment.
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  president
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Vladimir Putin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  has signed a bill into law prohibiting the use of digital assets, such as … [+1436 chars]Three
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Arrows Capital
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br>On
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tuesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , the distressed crypto hedge fund was ordered into liquidation by a Virgin… [+2515 chars]Elon
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Musk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# -owned electric vehicle making company
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has sold a significant amount of its
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  holdings, the firm said in a statement. Reporting its earnings for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Q2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# , the company said that it had … [+2850 chars]Grayscale
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Investments
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has announced its intention to sue
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Securities and Exchange Commission
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  after the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  regulator rejected its proposal to list a spot bitcoin
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ETF
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Just an hour
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  after the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SEC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  re… [+1567 chars]What a difference a year makes. After making big plays in Bitcoin in
# <mark cl

# %%
#list all Entities
for i in bitcoin_doc.ents:
    print(i.text, i.label_)
# Out:
# the Whinstone US Bitcoin ORG
# Rockdale GPE
# Texas GPE
# October 9th, 2021 DATE
# North Ameri GPE
# UK GPE
# mans NORP
# Russia GPE
# Russian NORP
# Vladimir Putin PERSON
# Arrows Capital ORG
# one CARDINAL
# Tuesday DATE
# Musk PERSON
# Tesla ORG
# Bitcoin NORP
# Q2 CARDINAL
# Investments ORG
# the Securities and Exchange Commission ORG
# US GPE
# ETF ORG
# Just an hour TIME
# SEC ORG
# 2021 DATE
# Tesla ORG
# $936 million MONEY
# the second quarter of 2022 DATE
# Bitcoin NORP
# 75 CARDINAL
# 2022 DATE
# Wednesday DATE
# $2.3 billion MONEY
# second-quarter DATE
# a record $3.3 billion MONEY
# first ORDINAL
# 27 CARDINAL
# Reuters ORG
# chars]July 19 DATE
# Reuters ORG
# months DATE
# chars]July 12 DATE
# Reuters ORG
# winter DATE
# two CARDINAL
# El Salvador GPE
# Nayib Bukele PERSON
# Bitcoin ORG
# more than 50 percent PERCENT
# this year DATE
# chars]NEW YORK GPE
# July 20 DATE
# Reuters ORG
# Wednesday DATE
# Tesla Inc ORG
# TSLA.O ORG
# about 75% PERCENT
# fiat ORG
# 29 CARDINAL
# Reuters ORG
# The U.S. Securities and Exchange Commission ORG
# Wednesday DATE
# Grayscale ORG
# 30 CARDINAL
# Reuters ORG
# 6.1% PERCENT
# 18,866.77 MONEY
# GMT WORK_OF_ART
# Thursday DATE
# 1,226.41 MONEY
# 60.9% PERCENT
# year DATE
# ten CARDINAL
# Wednesday DATE
# approximately 75% PERCENT
# chars]BRUSSELS PERSON
# June 30 DATE
# Reuters ORG
# Jacobi Asset Management ORG
# Thursday DATE
# Europe LOC
# first ORDINAL
# ETF ORG
# Democrats NORP
# the Environmental Protection Agency ORG
# Department of Energy ORG
# US GPE
# 2009 DATE
# the last few years DATE
# Bitcoin ORG
# the last month DATE
# Ethereum 2.0 ORG
# second ORDINAL
# chars]WASHINGTON GPE
# June 30 DATE
# Reuters ORG
# U.S. GPE
# Thursday DATE
# South African NORP
# first ORDINAL
# CNN Business' Before ORG
# Bell ORG
# chars]NEW YORK GPE
# July 19 DATE
# Reuters ORG
# Texas GPE
# July 21 DATE
# Reuters ORG
# Brazilian NORP
# Mercado Bitcoin PERSON
# Mexican NORP
# the end of the year DATE
# Latin Amer GPE
# the Central African Republic LOC
# Kristy Kilburn PERSON
# LONDON GPE
# June 30 DATE
# Reuters ORG
# The European Union ORG
# Thursday DATE
# Dutch NORP
# Ukraine GPE
# Salvador ORG
# 6.5 million CARDINAL
# Mexico GPE
# Bitso PRODUCT
# bitco ORG
# +4849 PERSON
# Fairlead Strategies' ORG
# Katie Stockton PERSON
# June DATE
# winter DATE
# 7,202 CARDINAL
# chars]NEW YORK GPE
# July 12 DATE
# Reuters ORG
# The U.S. Securities and Exchange Commission ORG
# Tuesday DATE
# Cathie Wood's ORG
# Arc Inves ORG
# the years DATE
# Monday DATE
# $1 trillion MONEY
# first ORDINAL
# June 13 DATE
# Musk PERSON
# Twitter PRODUCT
# Wednesday DATE
# Tesladumped ORG
# 75% PERCENT
# last quarter DATE
# 2008 DATE
# over 80% PERCENT
# last year DATE
# accordi PERSON
# Musk PERSON
# Twitter PRODUCT
# Wednesday DATE
# Tesladumped ORG
# 75% PERCENT
# last quarter DATE
# $222 million MONEY
# 75% PERCENT
# the Securities and Exchange Commission ORG
# Block GPE
# 2022 DATE
# chars]The European Union ORG
# Coinbase Global PERSON
# monthly DATE
# 2011 last month DATE
# six months DATE
# Xiaomi ORG
# one-inch QUANTITY
# 50.3 CARDINAL
# Sony ORG
# Sony ORG
# Xperia Pro PERSON
# James Howells PERSON
# UK GPE
# Newport GPE
# Wales GPE
# Texas GPE
# this October DATE
# GamesBeat Summit Next ORG
# today DATE
# Transform 2022 LAW
# July 19 and virtually DATE
# July 20 - 28 DATE
# today DATE
# Crypto PERSON
# the Ethereum Merge LAW
# 2014 DATE
# Merge PERSON
# second ORDINAL
# chars]LONDON ORG
# June 29 DATE
# Reuters ORG
# Three CARDINAL
# Arrows Capital ORG
# 3AC CARDINAL
# Reuters ORG
# Wednesday DATE
# July 25 DATE
# Reuters ORG
# Brazilian NORP
# XP Inc ORG
# XP.O DATE
# mid-August DATE
# 2014 DATE
# Merge PERSON
# second ORDINAL
# Scaramucci PRODUCT
# SkyBridge Capital ORG
# one CARDINAL
# Bloomberg GPE
# Legion Strategies ORG
# Howells GPE
# 6 CARDINAL
# Newport GPE
# Wales GPE
# two CARDINAL
# Blockchain.com ORG
# Kraken ORG
# Coinbase PERSON
# hundreds CARDINAL
# Justin Sullivan PERSON
# Getty Images ORG
# Nilay Patel PERSON
# earlier this year DATE
# this year DATE
# Howard Marks PERSON
# year DATE
# +2106 chars]Celsius PERSON
# a month ago DATE
# yesterday DATE
# $1.2 billion MONEY
# chars]LONDON ORG
# July 3 DATE
# Reuters ORG
# the Central African Republic LOC
# Faustin-Archange Touadera WORK_OF_ART
# Sunday DATE
# +1538 ORG
# Howells GPE
# 8,000 CARDINAL
# Mike Novogratz PERSON
# more than 50% PERCENT
# this year DATE
# +2431 chars]Critique ORG
# thousands CARDINAL
# Meta ORG
# Novi ORG
# chars]LONDON ORG
# July 13 DATE
# Reuters ORG
# Wednesday DATE
# chars]MUMBAI GPE
# July 6 DATE
# Reuters ORG
# India GPE
# up to 90% PERCENT
# US GPE
# Voyager Digital PERSON
# June 30 DATE
# Reuters ORG
# Singapore GPE
# Three CARDINAL
# Three CARDINAL
# millions CARDINAL
# recent years DATE
# August DATE
# Pokemon ORG
# Sky Mavis PERSON
# $15 million MONEY
# Thursday DATE
# Tesla ORG
# Nasdaq ORG
# Europe LOC
# Wednesday DATE
# Tesla ORG
# second-quarter DATE
# Cleve Mesidor PERSON
# Department of Commerce ORG
# Mesidor PERSON
# FTX ORG
# Sam Bankman-Fried PERSON
# Reuters ORG
# Wednesday DATE
# Thursday DATE
# Tesla ORG
# second-quarter DATE
# as high as 10% PERCENT
# +1360 chars]In PERSON
# 18th-century DATE
# Castle Craig PERSON
# Peebles GPE
# Roy ORG
# 29-year-old DATE
# Monday DATE
# last week DATE
# the second quarter DATE
# Last week DATE
# 49.99 MONEY
# Euros PERSON
# Voyager Digital Ltd. ORG
# Intelligent Sustainability ORG
# 24/7 CARDINAL
# Cleveland Working Paper ORG
# 22-19 DATE
# PagesPosted ORG
# 22 CARDINAL
# Jun 2022 ORG
# June 21, 2022
#  DATE
# Abstract ORG
# The Lightning Network ORG
# Bitcoin NORP
# US GPE
# Robert Kiyosaki PERSON
# this week DATE
# two CARDINAL
# Coinbase PERSON
# FTX ORG
# 2012 DATE
# Brian Armstrong PERSON
# Reuters ORG
# the bleak winter DATE
# Reuters ORG
# the bleak winter DATE
# chars]LONDON ORG
# July 5 DATE
# Reuters ORG
# Hilbert Capital PERSON
# Cevian Capital ORG
# Richard Murray PERSON
# Tuesday DATE
# Murray PERSON
# Thursday DATE
# millions of dollars MONEY
# HONG KONG GPE
# June 30 DATE
# Reuters ORG
# Thursday DATE
# U.S. GPE
# November 2021 DATE
# two-thirds CARDINAL
# $3 trillion MONEY
# Ignatova PERSON
# Cryptoqueen WORK_OF_ART
# FBI ORG
# Wanted Fugitive ORG
# billions of dollars MONEY
# Three CARDINAL
# Arrows Capital ORG
# just days DATE
# multimillion dollar MONEY
# Voyager PRODUCT
# +4584 ORG

# %% [markdown]
# ### Ethereum NER

# %%
#Concatenate all of the Ethereum text together
concat_ethereum = ethereum_df.text.str.cat()
concat_ethereum
# Out:
# 'Less than two weeks into its soft launch, GameStops NFT marketplace is already courting controversy. Among the NFTs listed on the platform is an artwork called Falling Man that was spotted by \r\nWeb3 … [+1429 chars]Axie Infinity was the prime example of crypto gaming last year, when its play-to-earn formula helped it reach up to 2.7 million daily active users last November. But that all came crashing down in Ma… [+1604 chars]The Ethereum Merge is significant, and not just for people who own crypto. In the works in one form or another since 2014, the long-delayed Merge will see the second biggest blockchain reduce its car… [+10658 chars]Ethereum and Bitcoin have nearly become household names. However, while they\'re often mentioned in tandem, they\'re far from the same.\xa0\r\nBitcoin was created as an alternative, decentralized currency. … [+9267 chars]Whether you own cryptocurrency or not, the Ethereum Merge is a big deal. In the works since 2014, the long-delayed Merge will see ethereum, the second-biggest blockchain behind bitcoin, become nearly… [+9848 chars]Ethereum will improve upon its scalability after the completion of the so-called surge, co-founder Vitalik Buterin said Thursday.\xa0\r\nAt the Ethereum Community Conference in Paris, he addressed overall… [+1344 chars]It\'s a way off the $4,800 all-time-high, but the ether cryptocurrency is showing signs of life after a long downward spiral that began in April. Following news that the long-awaited Ethereum Merge co… [+1616 chars]Over the last month, ether has significantly outperformed bitcoin as enthusiasm grows ahead of the highly anticipated "merge" event for Ethereum 2.0.\r\nThe second-largest cryptocurrency was hovering a… [+1359 chars]DeFi has been called the "wild west" of the cryptocurrency world. It\'s an unregulated financial system that many believe will revolutionize the way we conduct financial transactions.\r\nBut because it\'… [+7545 chars]Whether the first six months of 2022 have felt interminable or fleetingor bothmassive hacks, data breaches, digital scams, and ransomware attacks continued apace throughout the first half of this com… [+7775 chars]Three Arrows Capital, one of the crypto industrys biggest sinking ships, is finally being put out of its misery.\r\nOn Tuesday, the distressed crypto hedge fund was ordered into liquidation by a Virgin… [+2515 chars]June 28 (Reuters) - Investors in ether and its troubled twin stETH are nervously anticipating a crypto milestone: The merge.\r\nThat\'s the name for a major upgrade of the Ethereum blockchain network up… [+4468 chars]Crypto firms including Blockchain.com, Kraken and Coinbase are still recruiting hundreds of new staff despite recent mass layoffs and a collapse in the value of most digital coins.\r\nBlockchain.com ha… [+1708 chars]GameStop celebrated the launch of its NFT marketplace on Monday. Its Ethereum-based depot for virtually autographed JPEGs arrived just days after the meme stock giant ruthlessly laid off more employe… [+3028 chars]Anthony Scaramucci\'s SkyBridge Capital has suspended client withdrawals from one of its funds against a backdrop of a depreciating stock market, according to Bloomberg.\r\nThe Legion Strategies fund st… [+2214 chars]July 14 (Reuters) - Non-fungible token (NFT) marketplace OpenSea said on Thursday it would cut about 20% of its workforce to reduce costs in the face a prolonged slump in digital asset markets.\r\n"The… [+1400 chars]June 30 (Reuters) - Bitcoin dropped 6.1% to $18,866.77 at 2004 GMT on Thursday, putting the biggest and best-known cryptocurrency down $1,226.41 from its previous close and down 60.9% from the year\'s… [+1098 chars]Scams and frauds are ubiquitous in crypto, but sometimes the biggest losses are those people inflict upon themselves. On Wednesday, one NFT trader suffered a spectacular loss of 100 ether, or $150,00… [+2966 chars]The drivers for Intels Arc Alchemist GPUs seemingly do not support the ability to mine crypto currency.\r\nAs re ...

# %%
#Run the NER processor on all of the text
ethereum_doc = nlp(concat_ethereum)
ethereum_doc

#Add a title to the document
ethereum_doc.user_data['Title'] = 'Ethereum NER'

# %%
#Render the visualization
displacy.render(ethereum_doc, style = 'ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Less than two weeks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  into its soft launch,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     GameStops
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  NFT marketplace is already courting controversy. Among the NFTs listed on the platform is an artwork called
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Falling Man
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Web3 … [+1429 chars]Axie Infinity was the prime example of crypto gaming
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     last year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , when its play-to-earn formula helped it reach
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     up to 2.7 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     daily
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  active users
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     last November
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . But that all came crashing down in Ma… [+1604
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chars]The Ethereum Merge
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is significant, and not just for people who own crypto. In the works in one form or another since
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2014
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , the long-delayed
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Merge
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  will see the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     second
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# </br>Bitcoin was created as an alternative, decentralized currency. … [+9267 chars]Whether you own cryptocurrency or not,
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Ethereum Merge
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LAW</span>
# </mark>
#  is a big deal. In the works since
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2014
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , the long-delayed
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Merge
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  will see ethereum, the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     second
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# -biggest blockchain behind bitcoin, become nearly… [+9848 chars]Ethereum will improve upon its scalability after the completion of the so-called surge, co-founder
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Vitalik Buterin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Thursday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>At
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Ethereum Community Conference
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Paris
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , he addressed overall… [+1344 chars]It's a way off the $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4,800
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  all-time-high, but the ether cryptocurrency is showing signs of life after a long downward spiral that began in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     April
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . Following news that the long-awaited
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum Merge
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  co… [+1616 chars]Over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-hei

# %%
#List all Entities
for i in ethereum_doc.ents:
    print(i.text, i.label_)
# Out:
# Less than two weeks DATE
# GameStops ORG
# Falling Man PERSON
# last year DATE
# up to 2.7 million MONEY
# daily DATE
# last November DATE
# chars]The Ethereum Merge PERSON
# 2014 DATE
# Merge PERSON
# second ORDINAL
# the Ethereum Merge LAW
# 2014 DATE
# Merge PERSON
# second ORDINAL
# Vitalik Buterin PERSON
# Thursday DATE
# the Ethereum Community Conference ORG
# Paris GPE
# 4,800 MONEY
# April DATE
# Ethereum Merge ORG
# the last month DATE
# Ethereum 2.0 ORG
# second ORDINAL
# chars]DeFi GPE
# the "wild west PRODUCT
# the first six months of 2022 DATE
# the first half of this DATE
# Arrows Capital ORG
# one CARDINAL
# Tuesday DATE
# 28 CARDINAL
# Reuters ORG
# Ethereum ORG
# Blockchain.com ORG
# Kraken ORG
# Coinbase PERSON
# hundreds CARDINAL
# chars]GameStop ORG
# NFT ORG
# Monday DATE
# Ethereum ORG
# Scaramucci PRODUCT
# SkyBridge Capital ORG
# one CARDINAL
# Bloomberg GPE
# Legion Strategies ORG
# 14 CARDINAL
# Reuters ORG
# NFT ORG
# OpenSea ORG
# Thursday DATE
# about 20% PERCENT
# 30 CARDINAL
# Reuters ORG
# 6.1% PERCENT
# 18,866.77 MONEY
# GMT WORK_OF_ART
# Thursday DATE
# 1,226.41 MONEY
# 60.9% PERCENT
# year DATE
# Wednesday DATE
# one CARDINAL
# NFT ORG
# 100 CARDINAL
# 150,00 MONEY
# Intels Arc Alchemist ORG
# Toms Hardware GPE
# Intel ORG
# Arc A380 ORG
# chars]GameStop ORG
# NFT ORG
# Falling Man WORK_OF_ART
# millions CARDINAL
# recent years DATE
# winter DATE
# second ORDINAL
# around 40% PERCENT
# the past seven days DATE
# 1,6 MONEY
# Today DATE
# chars]The Fine Print: WORK_OF_ART
# Howard Marks PERSON
# year DATE
# recent years DATE
# July 19 DATE
# Phil Rosen PERSON
# NYC LOC
# 1969 DATE
# Neil Armstrong PERSON
# Buzz Aldrin PERSON
# five decades DATE
# a year ago DATE
# Phil Rosen PERSON
# Los Angeles GPE
# today DATE
# two CARDINAL
# Coinbase PERSON
# FTX ORG
# 2012 DATE
# Brian Armstrong PERSON
# Monday DATE
# $1 trillion MONEY
# first ORDINAL
# June 13 DATE
# NFT ORG
# 57 CARDINAL
# 150,000 MONEY
# Franklin Caldwell PERSON
# YouTube PRODUCT
# the British Army ORG
# Sunday DATE
# Elon Musk PRODUCT
# Army ORG
# 14 CARDINAL
# GameStop's PRODUCT
# NFT ORG
# NFT ORG
# NFT ORG
# millions CARDINAL
# only an estimated $44,5 MONEY
# Ethereum ORG
# Ethereum ORG
# Layer 2 PERSON
# 12-month DATE
# June DATE
# one CARDINAL
# PoS ORG
# PoS ORG
# Securities and Exchange Commission ORG
# Thursday DATE
# Coinbase PRODUCT
# Sameer Ramani PERSON
# this decade DATE
# 2020 DATE
# 2021 DATE
# Dan Frommer
#  PERSON
# many years DATE
# Ethereums ORG
# chars]Ethereum(ETH -6.68% PERCENT
# Ethereum ORG
# second ORDINAL
# 4,892 MONEY
# November 2021 DATE
# GameStop ORG
# NFT ORG
# earlier this month DATE
# one CARDINAL
# NFT ORG
# Falling Man PERSON
# September 11, 2001 DATE
# the years DATE
# $100 million MONEY
# last week DATE
# North Korean NORP
# chars]Monday DATE
# morning TIME
# the U.S. Securities and Exchange Commission ORG
# SEC ORG
# Gary Gensler PERSON
# CNBC ORG
# Squawk Box PERSON
# chars]NEW YORK GPE
# June 30 DATE
# Reuters ORG
# Doug Milnes PERSON
# January of this year DATE
# chars]July 5 DATE
# Reuters ORG
# NFT ORG
# last year DATE
# billions of dollars MONEY
# chars]July 5 DATE
# Reuters ORG
# NFT ORG
# last year DATE
# billions of dollars MONEY
# ETH 5.58% PERCENT
# Ethereu GPE
# Three CARDINAL
# Arrows Capital ORG
# just days DATE
# multimillion dollar MONEY
# Voyager PRODUCT
# +4584 ORG
# StackCommerce ORG
# the beginning of 2021 DATE
# November 2021 DATE
# -0.03% PERCENT
# 500% PERCENT
# Ethereum ORG
# roughly 75% PERCENT
# trad ORG
# Tuesday DATE
# Amazon ORG
# Tesla ORG
# -2.97% PERCENT
# Thursday DATE
# morning TIME
# weeks DATE
# Celsius Network PERSON
# +2524 chars]Ethereum(ETH -4.68% ORG
# more than 60% PERCENT
# this year DATE
# +3448 chars]Ethereum(ETH ORG
# -4.14% PERCENT
# second ORDINAL
# dApps ORG
# 1.9% PERCENT
# early afternoon TIME
# +2542 ORG
# Saturday DATE
# the day DATE
# about 11:45 a.m. TIME
# ET PERSON
# 6.17% PERCENT
# about 10% PERCENT
# chars]Ethereum(ETH 3.48% PERCENT
# the past two years DATE
# recent months DATE
# chars]Ethereum(ETH 1.54% PERCENT
# Shiba GPE
# -0.45% PERCENT
# Ethereum ORG
# second ORDINAL
# Sunday DATE
# last week DATE
# 4:00 TIME
# Ethereum(ETH -4.45% ORG
# more than 49% PERCENT
# the last three weeks DATE
# Sept. 19 DATE
# chars]In 2013 PERSON
# Cleve Mesidor PERSON
# Department of Commerce ORG
# Mesidor PERSON
# +4683 chars]In PERSON
# the last few weeks DATE
# Bitcoin ORG
# Coinbase Global PERSON
# 78.5% PERCENT
# November last year DATE
# over 26,000 CARDINAL
# over 12,000 CARDINAL
# 2019 DATE
# Thursday DATE
# the Reddit Avatar Builder ORG
# chars]GameStop ORG
# first ORDINAL
# May DATE
# Ethereum ORG
# Shiba ORG
# -3.97% PERCENT
# recent days DATE
# Ethereum(ETH -0.12% ORG
# -0.88% PERCENT
# a week DATE
# CoinMarketCap ORG
# Ethereum Classic ORG
# 72% PERCENT
# the past seven days DATE
# Mining Is Going Away WORK_OF_ART
# chars]GameStop ORG
# NFT ORG
# Monday DATE
# $3.5 million MONEY
# 50 CARDINAL
# NFT ORG
# Celsius Networks PERSON
# Chapter 11 LAW
# CNBC ORG
# late Wednesday TIME
# New Jersey GPE
# ETH ORG
# second ORDINAL
# last week's DATE
# BTC -1.69% PERCENT
# US GPE
# Houston GPE
# the next three years DATE
# Ethereum(ETH -7.58% PERCENT
# these days DATE
# Ethereum ORG
# one CARDINAL
# Dan Frommer
#  PERSON
# Sybil ORG
# 4.17% PERCENT
# 4,892 MONEY
# November 2021 DATE
# Ethereum ORG
# 77% PERCENT
# $1 trillion MONEY
# the weekend DATE
# a turbulent week DATE
# the Federal Reserve ORG
# July DATE
# 0.20% PERCENT
# this morning TIME
# recent days DATE
# 6.21% PERCENT
# Today DATE
# recent weeks DATE
# 12:30 p.m. ET TIME
# -4.00% PERCENT
# Ethereum(ETH -4.85% ORG
# 30% PERCENT
# just the past week DATE
# "The Merge WORK_OF_ART
# Sept. 19 DATE
# Ethereum ORG
# ETH 4.08% PERCENT
# metho PERSON
# today DATE
# this morning TIME
# 24 hours TIME
# this morning TIME
# later this week DATE
# the past 24 DATE
